# %% [markdown]
# Scraping College Stats

# %%
import pandas as pd
import numpy as np
import requests
import lxml.html as lh
from bs4 import BeautifulSoup
import os

# %%
file = '//Users//chung-tsengwang//Desktop//Github Repo//Predicting-NBA-Rookie-Stats//data//processed//processed_nba.csv'
nba = pd.read_csv(file)
nba.head()
# Out:
#    Unnamed: 0  year                  Player  Age  NBA_G  NBA_FGP  NBA_3PP  \
# 0           0  2019            Jaylen Adams   22     34    0.345    0.338
# 1           1  2019               Deng Adel   21     19    0.306    0.261
# 2           2  2019  DeVaughn Akoon-Purcell   25      7    0.300    0.000
# 3           3  2019            Rawle Alkins   21     10    0.333    0.250
# 4           4  2019           Grayson Allen   23     38    0.376    0.323
#
#    NBA_FTP  NBA_PTS  NBA_TRB  NBA_AST   NBA_STL   NBA_BLK   NBA_TOV
# 0    0.778      3.2      1.8      1.9  0.411765  0.147059  0.823529
# 1    1.000      1.7      1.0      0.3  0.052632  0.210526  0.315789
# 2    0.500      1.0      0.6      0.9  0.285714  0.000000  0.285714
# 3    0.667      3.7      2.6      1.3  0.100000  0.000000  0.800000
# 4    0.750      5.6      0.6      0.7  0.157895  0.157895  0.868421

# %%
players_list = nba['Player'].values
len(players_list)
# Out:
# 892

# %%
data = []
for player in players_list:
    url_name = player
    player = player.lower()
    player = player.replace('.','')
    player = player.replace("'",'')
    player = player.replace(' ','-')
    website_url = requests.get('https://www.sports-reference.com/cbb/players/'+ player +'-1.html')
    soup = BeautifulSoup(website_url.content,'lxml')
    table = soup.find('table',{'id':'players_per_game'})
    if table is not None:
        data = data + [url_name]
        stats = table.findAll('td')
        elements = []
        for n in stats:
            elements.append(n.get_text())
        data = data + elements[-28:]

# %%
transformed = np.reshape(np.array(data),(-1,29))

# %%
#To get column headers
headers = ['Player','School','Conf','G','GS','MP','FG','FGA','FGP','2P','2PA','2PP','3P','3PA','3P%','FT','FTA','FTP','ORB','DRB','TRB','AST','STL','BLK','TOV','PF','PTS','nan','SOS']
college = pd.DataFrame(transformed, columns = headers)
college = college.drop(['Conf','GS','MP','FG','FGA','2P','2PA','2PP','3P','3PA','FT','FTA','ORB','DRB','nan','SOS','PF'], axis = 1)
college.head()
# Out:
#                    Player           School    G   FGP   3P%   FTP  TRB  AST  \
# 0            Jaylen Adams  St. Bonaventure  110  .427  .394  .838  3.4  5.4
# 1               Deng Adel       Louisville   89  .438  .348  .776  4.1  2.0
# 2  DeVaughn Akoon-Purcell   Illinois State   60  .428  .301  .739  5.3  1.6
# 3            Rawle Alkins          Arizona   60  .450  .365  .729  4.9  2.2
# 4           Grayson Allen             Duke  142  .430  .380  .834  3.2  3.0
#
#    STL  BLK  TOV   PTS
# 0  1.5  0.2  2.9  17.4
# 1  0.5  0.3  1.7  11.2
# 2  1.0  0.3  2.3  13.5
# 3  1.0  0.6  2.1  11.8
# 4  1.0  0.1  1.7  14.1

# %%
college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 738 entries, 0 to 737
# Data columns (total 12 columns):
# Player    738 non-null object
# School    738 non-null object
# G         738 non-null object
# FGP       738 non-null object
# 3P%       738 non-null object
# FTP       738 non-null object
# TRB       738 non-null object
# AST       738 non-null object
# STL       738 non-null object
# BLK       738 non-null object
# TOV       738 non-null object
# PTS       738 non-null object
# dtypes: object(12)
# memory usage: 69.3+ KB

# %%
college.describe()
# Out:
#                Player    School    G   FGP  3P%   FTP  TRB  AST  STL  BLK  \
# count             738       738  738   738  738   738  738  738  738  738
# unique            735       191  139   247  221   313  109   70   30   39
# top     Chris Johnson  Kentucky   35  .450       .733  4.8  1.5  0.9  0.1
# freq                2        37   18    14   56     9   22   35   63   94
#
#         TOV   PTS
# count   738   738
# unique   45   187
# top     1.5  14.1
# freq     51    13

# %%
college.to_csv('raw_college.csv', index = False)

# %%
file2 = '//Users//chung-tsengwang//Desktop//Github Repo//Predicting-NBA-Rookie-Stats//data//EDA datasets//2020_college_fullset.csv'
college_2020 = pd.read_csv(file2)
college_2020['year'] = 2020
college_2020.head()
# Out:
#             Player      School   G  GS    MP   FG   FGA    FGP   2P   2PA  \
# 0  Zion Williamson        Duke  33  33  30.0  9.0  13.2  0.680  8.2  11.0
# 1       RJ Barrett        Duke  38  38  35.3  8.4  18.5  0.454  6.5  12.2
# 2  De'Andre Hunter    Virginia  71  38  26.6  4.4   8.5  0.509  3.4   6.3
# 3   Darius Garland  Vanderbilt   5   5  27.8  5.8  10.8  0.537  3.6   6.2
# 4   Jarrett Culver  Texas Tech  75  58  29.5  5.3  11.6  0.459  3.9   7.5
#
#    ...   DRB  TRB  AST  STL  BLK  TOV   PF   PTS    SOS  year
# 0  ...   5.4  8.9  2.1  2.1  1.8  2.4  2.1  22.6  11.97  2020
# 1  ...   6.0  7.6  4.3  0.9  0.4  3.2  1.8  22.6  11.97  2020
# 2  ...   3.1  4.4  1.6  0.6  0.5  1.2  1.9  12.4   9.61  2020
# 3  ...   3.4  3.8  2.6  0.8  0.4  3.0  1.4  16.2   7.79  2020
# 4  ...   4.4  5.6  2.8  1.3  0.6  2.1  2.0  14.9   9.56  2020
#
# [5 rows x 28 columns]

# %%
headers = ['Player','School','Conf','G','GS','MP','FG','FGA','FGP','2P','2PA','2PP','3P','3PA','3P%','FT','FTA','FTP','ORB','DRB','TRB','AST','STL','BLK','TOV','PF','PTS','nan','SOS']
full_college_stats = pd.DataFrame(transformed, columns = headers)
full_college_stats = full_college_stats.drop(['Conf','nan'],axis = 1)
full_college_stats.head()
# Out:
#                    Player           School    G   GS    MP   FG   FGA   FGP  \
# 0            Jaylen Adams  St. Bonaventure  110  108  36.3  4.8  11.3  .427
# 1               Deng Adel       Louisville   89   71  26.8  3.9   9.0  .438
# 2  DeVaughn Akoon-Purcell   Illinois State   60   48  27.2  4.6  10.7  .428
# 3            Rawle Alkins          Arizona   60   57  29.3  4.0   9.0  .450
# 4           Grayson Allen             Duke  142   97  27.9  4.3   9.9  .430
#
#     2P  2PA  ...    ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS    SOS
# 0  2.4  5.1  ...    0.5  2.8  3.4  5.4  1.5  0.2  2.9  2.6  17.4   1.82
# 1  2.8  5.7  ...    0.6  3.5  4.1  2.0  0.5  0.3  1.7  1.5  11.2   9.32
# 2  3.8  8.0  ...    1.7  3.6  5.3  1.6  1.0  0.3  2.3  1.9  13.5   2.73
# 3  2.8  5.5  ...    1.7  3.2  4.9  2.2  1.0  0.6  2.1  2.2  11.8   7.24
# 4  2.2  4.5  ...    0.5  2.6  3.2  3.0  1.0  0.1  1.7  2.1  14.1  10.27
#
# [5 rows x 27 columns]

# %%
nba_years = pd.DataFrame(nba[['Player','year']])
nba_years.head()
# Out:
#                    Player  year
# 0            Jaylen Adams  2019
# 1               Deng Adel  2019
# 2  DeVaughn Akoon-Purcell  2019
# 3            Rawle Alkins  2019
# 4           Grayson Allen  2019

# %%
full_college_stats = full_college_stats.merge(nba_years,how = 'left', on = 'Player')
full_college_stats.head()
# Out:
#                    Player           School    G   GS    MP   FG   FGA   FGP  \
# 0            Jaylen Adams  St. Bonaventure  110  108  36.3  4.8  11.3  .427
# 1               Deng Adel       Louisville   89   71  26.8  3.9   9.0  .438
# 2  DeVaughn Akoon-Purcell   Illinois State   60   48  27.2  4.6  10.7  .428
# 3            Rawle Alkins          Arizona   60   57  29.3  4.0   9.0  .450
# 4           Grayson Allen             Duke  142   97  27.9  4.3   9.9  .430
#
#     2P  2PA  ...   DRB  TRB  AST  STL  BLK  TOV   PF   PTS    SOS  year
# 0  2.4  5.1  ...   2.8  3.4  5.4  1.5  0.2  2.9  2.6  17.4   1.82  2019
# 1  2.8  5.7  ...   3.5  4.1  2.0  0.5  0.3  1.7  1.5  11.2   9.32  2019
# 2  3.8  8.0  ...   3.6  5.3  1.6  1.0  0.3  2.3  1.9  13.5   2.73  2019
# 3  2.8  5.5  ...   3.2  4.9  2.2  1.0  0.6  2.1  2.2  11.8   7.24  2019
# 4  2.2  4.5  ...   2.6  3.2  3.0  1.0  0.1  1.7  2.1  14.1  10.27  2019
#
# [5 rows x 28 columns]

# %%
full_college_stats = full_college_stats.append(college_2020, ignore_index = True)
full_college_stats[full_college_stats['year'] == 2020]
# Out:
#                        Player                 School    G   GS    MP   FG  \
# 749           Zion Williamson                   Duke   33   33    30    9
# 750                RJ Barrett                   Duke   38   38  35.3  8.4
# 751           De'Andre Hunter               Virginia   71   38  26.6  4.4
# 752            Darius Garland             Vanderbilt    5    5  27.8  5.8
# 753            Jarrett Culver             Texas Tech   75   58  29.5  5.3
# 754                Coby White                    UNC   35   35  28.5  5.4
# 755              Jaxson Hayes                  Texas   32   21  23.3  3.8
# 756             Rui Hachimura                Gonzaga  102   39  19.7  4.5
# 757               Cam Reddish                   Duke   36   35  29.7  4.3
# 781  12.6  0.476  4.7   9.4  ...   3.7  4.6  2.9  1.2  0.3  2.7  2.5  16.1
# 782  14.7  0.561  6.8  11.9  ...   7.4  9.6    1  0.8  2.7    2  1.7    21
# 783   6.1  0.476  2.4   4.6  ...   3.9  5.5  1.5  0.8  1.6  1.6  2.8   8.1
# 784  10.9  0.406    3   6.4  ...   4.2  4.9  2.3  1.3  0.7  1.7  2.3  11.8
# 785    11  0.462  3.6   7.1  ...   4.3  5.4  0.8  0.7  0.5  1.2  2.1  14.8
# 786   6.5  0.552  3.2   5.4  ...   3.2  5.1  1.9  0.8  0.2  1.4    2   9.4
# 787  11.2   0.48    4   7.4  ...   3.7  5.2  2.4  1.5  0.4  2.3  2.3  15.4
# 788  11.6  0.487  4.7     9  ...     6  7.9  1.7  1.2  0.7  2.6  2.9  15.6
# 789  12.2  0.423  3.2   6.5  ...   2.8  3.1  5.9  2.5  0.1  3.2  2.1  15.6
# 790    10  0.504  4.6   8.6  ...   5.8  7.9  1.5    1  0.5  1.8  2.6  13.2
# 791  13.6  0.483  4.3   7.8  ...   2.6  2.9  2.1  0.7  0.2  1.7  1.6  18.6
# 792  13.6  0.496  4.6   8.2  ...   3.5  4.9    2  0.9  0.2  2.7  2.1  18.7
# 793  10.1  0.433    2   4.5  ...   2.6    3  1.6  0.7    0  1.1  1.1  12.5
# 794   9.9  0.409  2.4   5.4  ...   3.3  3.8  4.4  1.2  0.2  2.5  1.4  12.1
# 795   8.4  0.424  2.6   5.7  ...   2.1  2.4  4.3  0.7  0.1  1.6  1.2   9.7
# 796  12.1  0.428  3.2   6.5  ...   5.4  6.2  3.3  0.9    1  2.6  2.8    15
#
#        SOS  year
# 749  11.97  2020
# 750  11.97  2020
# 751   9.61  2020
# 752   7.79  2020
# 753   9.56  2020
# 754  11.35  2020
# 755  11.46  2020
# 756   3.91  2020
# 757  11.97  2020
# 758  -4.62  2020
# 759  10.51  2020
# 760  10.29  2020
# 761   10.1  2020
# 762   9.11  2020
# 763   7.25  2020
# 764      7  2020
# 765    NaN  2020
# 766  10.15  2020
# 767  10.05  2020
# 768  11.35  2020
# 769  -2.32  2020
# 770   9.38  2020
# 771   9.98  2020
# 772  10.29  2020
# 773    8.5  2020
# 774   9.84  2020
# 775   9.02  2020
# 776    NaN  2020
# 777   9.31  2020
# 778  -8.16  2020
# 779    NaN  2020
# 780   9.58  2020
# 781   6.54  2020
# 782   6.13  2020
# 783   9.79  2020
# 784    9.3  2020
# 785  10.55  2020
# 786   8.95  2020
# 787   6.95  2020
# 788   -1.6  2020
# 789   8.59  2020
# 790   3.19  2020
# 791  -1.81  2020
# 792    NaN  2020
# 793  10.05  2020
# 794   6.82  2020
# 795  10.15  2020
# 796  -2.08  2020
#
# [48 rows x 28 columns]

# %%
full_college_stats.to_csv('full_college_stats.csv',index = False)

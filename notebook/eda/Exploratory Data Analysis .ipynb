# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Trend Analysis

# %% [markdown]
# ## College Trends

# %%
file = '//Users//chung-tsengwang//Desktop//Github Repo//Predicting-NBA-Rookie-Stats//data//EDA datasets//full_college_stats.csv'
college = pd.read_csv(file)
college.head()
# Out:
#           Player               School    G     GS    MP   FG   FGA    FGP  \
# 0     Trae Young             Oklahoma   32   32.0  35.4  8.2  19.3  0.422
# 1   Josh Akognon  Cal State Fullerton   64   64.0  33.6  7.2  17.0  0.422
# 2  Stephen Curry             Davidson  104  103.0  32.6  8.4  17.9  0.467
# 3  Lester Hudson            UT-Martin   65   64.0  36.5  9.3  20.4  0.456
# 4      Gary Neal               Towson   49   46.0  36.1  8.3  18.6  0.446
#
#     2P   2PA  ...   DRB  TRB  AST  STL  BLK  TOV   PF   PTS    SOS  year
# 0  4.5   9.1  ...   3.5  3.9  8.7  1.7  0.3  5.2  1.8  27.4  10.56  2019
# 1  3.3   6.7  ...   2.7  3.3  1.5  1.2  0.1  2.2  2.1  22.0    NaN  2013
# 2  4.4   8.3  ...   3.8  4.5  3.7  2.1  0.3  3.0  2.4  25.3  -1.31  2010
# 3  5.8  10.8  ...   5.7  7.9  4.4  2.6  0.6  3.6  2.7  26.6  -5.64  2010
# 4  5.1   9.8  ...   3.3  4.1  3.3  1.6  0.2  2.7  2.3  25.6    NaN  2011
#
# [5 rows x 28 columns]

# %%
college.columns
# Out:
# Index(['Player', 'School', 'G', 'GS', 'MP', 'FG', 'FGA', 'FGP', '2P', '2PA',
#        '2PP', '3P', '3PA', '3P%', 'FT', 'FTA', 'FTP', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'SOS', 'year'],
#       dtype='object')

# %% [markdown]
# ### Points

# %%
plt.rcParams.update({'font.size': 16})
sns.set_style('darkgrid')
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs Points Scored')
sns.boxplot(college['year'], college['PTS'], ax=ax)
sns.pointplot(x='year', y='PTS', data=college.groupby('year', as_index=False).mean(), ax=ax)
plt.xlabel('Year')
plt.ylabel('Points')
plt.show()

# %% [markdown]
# ### Assist

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs Assists')
sns.boxplot(college['year'], college['AST'], ax=ax)
sns.pointplot(x='year', y='AST', data=college.groupby('year', as_index=False).mean(), ax=ax)
plt.xlabel('Year')
plt.ylabel('Assists')
plt.show()

# %% [markdown]
# ### Rebounds

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs Rebounds')
sns.boxplot(college['year'], college['TRB'], ax=ax)
sns.pointplot(x='year', y='TRB', data=college.groupby('year', as_index=False).mean(), ax=ax)
plt.xlabel('Year')
plt.ylabel('Rebounds')
plt.show()

# %% [markdown]
# ### 3-Pointers Attempted Per Games

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs 3PA')
sns.boxplot(college['year'], college['3PA'], ax=ax)
sns.pointplot(x='year', y='3PA', data=college.groupby('year', as_index=False).mean(), ax=ax)
plt.xlabel('Year')
plt.ylabel('3PA')
plt.show()

# %% [markdown]
# ### 3-Pointer Percentages

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs 3P%')
sns.boxplot(college['year'], college['3P%'], ax=ax)
sns.pointplot(x='year', y='3P%', data=college.groupby('year', as_index=False).mean(), ax=ax)
plt.ylim(0.0,0.7)
plt.xlabel('Year')
plt.ylabel('3P%')
plt.show()

# %% [markdown]
# ### Strength of Schedule

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs SOS')
sns.boxplot(college['year'], college['SOS'], ax=ax)
sns.pointplot(x='year', y='SOS', data=college.groupby('year', as_index=False).mean(), ax=ax)
plt.xlabel('Year')
plt.ylabel('SOS')
plt.show()

# %% [markdown]
# ### Turnover

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs TOV')
sns.boxplot(college['year'], college['TOV'], ax=ax)
sns.pointplot(x='year', y='TOV', data=college.groupby('year', as_index=False).mean(), ax=ax)
plt.xlabel('Year')
plt.ylabel('TOV')
plt.show()

# %% [markdown]
# ## NBA Trends

# %%
file = '//Users//chung-tsengwang//Desktop//Github Repo//Predicting-NBA-Rookie-Stats//data//raw//nba_stats_raw.csv'
nba = pd.read_csv(file)
nba.head()
# Out:
#    year                  Player         id                   Debut  Age  Yrs  \
# 0  2019            Jaylen Adams  adamsja01    Oct 17 '18 ATL @ NYK   22    1
# 1  2019               Deng Adel   adelde01    Jan 19 '19 CLE @ DEN   21    1
# 2  2019  DeVaughn Akoon-Purcell  akoonde01  Oct 23 '18 DEN vs. SAC   25    1
# 3  2019            Rawle Alkins  alkinra01    Dec 17 '18 CHI @ OKC   21    1
# 4  2019           Grayson Allen  allengr01  Oct 22 '18 UTA vs. MEM   23    1
#
#     G   MP  FG  FGA  ...    TOV  PF  PTS    FG%    3P%    FT%  MP.1  PS/G  \
# 0  34  428  38  110  ...     28  45  108  0.345  0.338  0.778  12.6   3.2
# 1  19  194  11   36  ...      6  13   32  0.306  0.261  1.000  10.2   1.7
# 2   7   22   3   10  ...      2   4    7  0.300  0.000  0.500   3.1   1.0
# 3  10  120  13   39  ...      8   7   37  0.333  0.250  0.667  12.0   3.7
# 4  38  416  67  178  ...     33  47  211  0.376  0.323  0.750  10.9   5.6
#
#    TRB/G  AST/G
# 0    1.8    1.9
# 1    1.0    0.3
# 2    0.6    0.9
# 3    2.6    1.3
# 4    0.6    0.7
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Points

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs PTS')
sns.boxplot(nba['year'], nba['PS/G'], ax=ax)
sns.pointplot(x='year', y='PS/G', data=nba.groupby('year', as_index=False).mean(), ax=ax)
plt.xlabel('Year')
plt.ylabel('PTS')
plt.show()

# %% [markdown]
# ### Assists

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs AST')
sns.boxplot(nba['year'], nba['AST/G'], ax=ax)
sns.pointplot(x='year', y='AST/G', data=nba.groupby('year', as_index=False).mean(), ax=ax)
plt.ylim(0.0,5)
plt.xlabel('Year')
plt.ylabel('AST')
plt.show()

# %% [markdown]
# ### 3-Point Percentages

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs 3P%')
sns.boxplot(nba['year'], nba['3P%'], ax=ax)
sns.pointplot(x='year', y='3P%', data=nba.groupby('year', as_index=False).mean(), ax=ax)
plt.ylim(0.0,0.7)
plt.xlabel('Year')
plt.ylabel('3P%')
plt.show()

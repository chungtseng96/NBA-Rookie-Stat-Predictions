# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### College Trends

# %%
file = '//Users//chung-tsengwang//Desktop//Github Repo//Predicting-NBA-Rookie-Stats//data//EDA datasets//full_college_stats.csv'
college = pd.read_csv(file)
college.head()
# Out:
#                    Player           School    G     GS    MP   FG   FGA  \
# 0            Jaylen Adams  St. Bonaventure  110  108.0  36.3  4.8  11.3
# 1               Deng Adel       Louisville   89   71.0  26.8  3.9   9.0
# 2  DeVaughn Akoon-Purcell   Illinois State   60   48.0  27.2  4.6  10.7
# 3            Rawle Alkins          Arizona   60   57.0  29.3  4.0   9.0
# 4           Grayson Allen             Duke  142   97.0  27.9  4.3   9.9
#
#      FGP   2P  2PA  ...   DRB  TRB  AST  STL  BLK  TOV   PF   PTS    SOS  year
# 0  0.427  2.4  5.1  ...   2.8  3.4  5.4  1.5  0.2  2.9  2.6  17.4   1.82  2019
# 1  0.438  2.8  5.7  ...   3.5  4.1  2.0  0.5  0.3  1.7  1.5  11.2   9.32  2019
# 2  0.428  3.8  8.0  ...   3.6  5.3  1.6  1.0  0.3  2.3  1.9  13.5   2.73  2019
# 3  0.450  2.8  5.5  ...   3.2  4.9  2.2  1.0  0.6  2.1  2.2  11.8   7.24  2019
# 4  0.430  2.2  4.5  ...   2.6  3.2  3.0  1.0  0.1  1.7  2.1  14.1  10.27  2019
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Points

# %%
plt.rcParams.update({'font.size': 16})
sns.set_style('darkgrid')
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs Points Scored')
sns.boxplot(college['year'], college['PTS'], ax=ax)
plt.xlabel('Year')
plt.ylabel('Points')
plt.show()

# %% [markdown]
# ### Assist

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs Assists')
sns.boxplot(college['year'], college['AST'], ax=ax)
plt.xlabel('Year')
plt.ylabel('Assists')
plt.show()

# %% [markdown]
# ### Rebounds

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs Rebounds')
sns.boxplot(college['year'], college['TRB'], ax=ax)
plt.xlabel('Year')
plt.ylabel('Rebounds')
plt.show()

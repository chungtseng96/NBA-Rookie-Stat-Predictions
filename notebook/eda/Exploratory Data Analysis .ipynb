# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Trend Analysis

# %% [markdown]
# ## College Trends

# %%
#file = '//Users//chung-tsengwang//Desktop//Github Repo//Predicting-NBA-Rookie-Stats//data//EDA datasets//full_college_stats.csv'
file = 'C:\\Users\\Chung-Tseng Wang\\Desktop\\NBA-Rookie-Stat-Predictions\\data\\processed\\final.csv'
data = pd.read_csv(file)
data.head()
# Out:
#    year            Player Position  Age      G       GS        MP   FG   FGA  \
# 0  2017  Marshall Plumlee   Center   24  124.0  36.0000  14.30000  1.3   1.9
# 1  2016  Chris McCullough  Forward   20   16.0  16.0000  28.10000  3.4   7.1
# 2  2015       Drew Gordon  Forward   24   61.0  53.0000  29.60000  5.3  10.0
# 3  2015     Tyler Johnson    Guard   22    5.0  69.2525  27.27375  0.2   0.6
# 4  2014       Jeff Withey   Center   23  117.0  76.0000  19.80000  2.8   4.9
#
#      FGP    ...     NBA_G  NBA_FGP   NBA_3PP  NBA_FTP  NBA_PTS  NBA_TRB  \
# 0  0.665    ...        29    0.515  0.283958    0.571      1.9      2.3
# 1  0.478    ...        59    0.426  0.306000    0.548      3.3      1.9
# 2  0.535    ...         9    0.421  0.000000    0.500      1.9      2.0
# 3  0.333    ...       270    0.433  0.364000    0.771     11.0      3.3
# 4  0.568    ...       206    0.525  0.143000    0.716      3.2      2.5
#
#    NBA_AST   NBA_STL   NBA_BLK   NBA_TOV
# ...

# %%
data.columns
# Out:
# Index(['year', 'Player', 'Position', 'Age', 'G', 'GS', 'MP', 'FG', 'FGA',
#        'FGP', '2P', '2PA', '2PP', '3P', '3PA', '3P%', 'FT', 'FTA', 'FTP',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PTS', 'SOS', 'PER',
#        'eFGP', 'WS', 'NBA_G', 'NBA_FGP', 'NBA_3PP', 'NBA_FTP', 'NBA_PTS',
#        'NBA_TRB', 'NBA_AST', 'NBA_STL', 'NBA_BLK', 'NBA_TOV'],
#       dtype='object')

# %% [markdown]
# ### PER

# %%
plt.rcParams.update({'font.size': 16})
sns.set_style('darkgrid')
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs PER')
sns.boxplot(data['year'], data['PER'], ax=ax)
sns.pointplot(x='year', y='PER', data=data.groupby('year', as_index=False).mean(), ax=ax)
plt.xlabel('Year')
plt.ylabel('Player Efficiency Rating')
plt.show()

# %% [markdown]
# ### eFGP

# %%
plt.rcParams.update({'font.size': 16})
sns.set_style('darkgrid')
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs Effective Field Goal Percentage')
sns.boxplot(data['year'], data['eFGP'], ax=ax)
sns.pointplot(x='year', y='eFGP', data=data.groupby('year', as_index=False).mean(), ax=ax)
plt.ylim(30,70)
plt.xlabel('Year')
plt.ylabel('eFGP')
plt.show()

# %% [markdown]
# ### Win Share

# %%
plt.rcParams.update({'font.size': 16})
sns.set_style('darkgrid')
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs Player Win Share')
sns.boxplot(data['year'], data['WS'], ax=ax)
sns.pointplot(x='year', y='WS', data=data.groupby('year', as_index=False).mean(), ax=ax)
plt.xlabel('Year')
plt.ylabel('WS')
plt.show()

# %% [markdown]
# ### Points

# %%
plt.rcParams.update({'font.size': 16})
sns.set_style('darkgrid')
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs Points Scored')
sns.boxplot(data['year'], college['PTS'], ax=ax)
sns.pointplot(x='year', y='PTS', data=data.groupby('year', as_index=False).mean(), ax=ax)
plt.xlabel('Year')
plt.ylabel('Points')
plt.show()

# %% [markdown]
# ### Assist

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs Assists')
sns.boxplot(data['year'], data['AST'], ax=ax)
sns.pointplot(x='year', y='AST', data=data.groupby('year', as_index=False).mean(), ax=ax)
plt.xlabel('Year')
plt.ylabel('Assists')
plt.show()

# %% [markdown]
# ### Rebounds

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs Rebounds')
sns.boxplot(data['year'], data['TRB'], ax=ax)
sns.pointplot(x='year', y='TRB', data=data.groupby('year', as_index=False).mean(), ax=ax)
plt.xlabel('Year')
plt.ylabel('Rebounds')
plt.show()

# %% [markdown]
# ### 3-Pointers Attempted Per Games

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs 3PA')
sns.boxplot(data['year'], data['3PA'], ax=ax)
sns.pointplot(x='year', y='3PA', data=data.groupby('year', as_index=False).mean(), ax=ax)
plt.xlabel('Year')
plt.ylabel('3PA')
plt.show()

# %% [markdown]
# ### 3-Pointer Percentages

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs 3P%')
sns.boxplot(data['year'], data['3P%'], ax=ax)
sns.pointplot(x='year', y='3P%', data=data.groupby('year', as_index=False).mean(), ax=ax)
plt.ylim(0.0,0.6)
plt.xlabel('Year')
plt.ylabel('3P%')
plt.show()

# %% [markdown]
# ### Turnover

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs TOV')
sns.boxplot(college['year'], college['TOV'], ax=ax)
sns.pointplot(x='year', y='TOV', data=college.groupby('year', as_index=False).mean(), ax=ax)
plt.xlabel('Year')
plt.ylabel('TOV')
plt.show()

# %% [markdown]
# ### Position Count

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs Position')
sns.countplot(x = data['year'],hue = 'Position', data=data)
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### 3PA by forwards

# %%
forwards = data[data['Position'] == 'Forward']
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs 3PA by Forwards')
sns.boxplot(forwards['year'], forwards['3PA'], ax=ax)
sns.pointplot(x='year', y='3PA', data=forwards.groupby('year', as_index=False).mean(), ax=ax)
plt.xlabel('Year')
plt.ylabel('3PA by forwards')
plt.show()

# %% [markdown]
# ### 3PA by forwards

# %%
guards = data[data['Position'] == 'Guard']
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs 3PA by Guards')
sns.boxplot(guards['year'], guards['3PA'], ax=ax)
sns.pointplot(x='year', y='3PA', data=guards.groupby('year', as_index=False).mean(), ax=ax)
plt.xlabel('Year')
plt.ylabel('3PA by Guards')
plt.show()

# %% [markdown]
# ## NBA Trends

# %%
file = '//Users//chung-tsengwang//Desktop//Github Repo//Predicting-NBA-Rookie-Stats//data//raw//nba_stats_raw.csv'
nba = pd.read_csv(file)
nba.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-c6acfe04b61e> in <module>()
#       1 file = '//Users//chung-tsengwang//Desktop//Github Repo//Predicting-NBA-Rookie-Stats//data//raw//nba_stats_raw.csv'
# ----> 2 nba = pd.read_csv(file)
#       3 nba.head()
#
# ...

# %% [markdown]
# ### Points

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs PTS')
sns.boxplot(nba['year'], nba['PS/G'], ax=ax)
sns.pointplot(x='year', y='PS/G', data=nba.groupby('year', as_index=False).mean(), ax=ax)
plt.xlabel('Year')
plt.ylabel('PTS')
plt.show()

# %% [markdown]
# ### Assists

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs AST')
sns.boxplot(nba['year'], nba['AST/G'], ax=ax)
sns.pointplot(x='year', y='AST/G', data=nba.groupby('year', as_index=False).mean(), ax=ax)
plt.ylim(0.0,5)
plt.xlabel('Year')
plt.ylabel('AST')
plt.show()

# %% [markdown]
# ### 3-Point Percentages

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Year vs 3P%')
sns.boxplot(nba['year'], nba['3P%'], ax=ax)
sns.pointplot(x='year', y='3P%', data=nba.groupby('year', as_index=False).mean(), ax=ax)
plt.ylim(0.0,0.7)
plt.xlabel('Year')
plt.ylabel('3P%')
plt.show()
